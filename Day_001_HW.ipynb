# %% [markdown]
# # 作業1：
#
# > 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料
#
# https://www.kaggle.com/wendykan/lending-club-loan-data
#
# 這是 Wendy Kan 約在三年前上傳的 Lending Club Peer-to-Peer 借款案件資料
#
#
# > 並寫下：
# > 1. 你選的這組資料為何重要
#
# 預測借款案件是否易成為呆帳，減少投資人損失
#
# > 2. 資料從何而來
#
# Lending Club 案件資料
#
# > 3. 蒐集而來的資料型態為何
#
# 結構化的表格
#
# > 4. 這組資料想解決的問題如何評估
#
# ...正確率？

# %% [markdown]
# # 作業2：
#
# > 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
# > 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#
# 業績一般來說會會認為是載客車輛所能產生的營業額，但是既然本身是經營者，提高利潤降低成本都是提升的一部分
#
# 以載客車輛來說，營業主要收入為載客，所以重點在於如何快速的載到下一個客人，以及如何避開容易有問題客人的區域
# 其次則可以考慮異業合作，例如餐飲業的
# 而支出方面，主要體現在於車輛維修，司機精神與體能狀況以及油耗上
#
# 因此應該會從如何減低空車率，巡航時往哪些點靠近（容易有客人需要搭車），減低支出，要避開哪些點（易有事故，奧客，路線複雜），路徑規劃（油耗），司機狀況確認（精神體力確認）... 等幾個方面去分析
#
# > 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#
# 內部資料來源主要從車輛 GPS 資料，跳表起算，結算，油資發票，司機無線電通話紀錄搜集
#
# 外部資料來源主要從車禍事故新聞，政府道路維修公告，油價公告
#
# > 3. 蒐集而來的資料型態為何
#
# GPS 資料，跳表資料會是車輛識別碼，時間與 geolocation 構成的結構化表格
#
# 郵資發票會是車輛識別碼，發票時間，發票金額構成的結構化表格
#
# 無線電通話紀錄會是車輛識別碼，發話時間，發話長度構成的結構化表格
#
# > 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#
# ...ROC?

# %% [markdown]
# # 作業3：
#
# > 請點選檢視範例依照 Day_001_example_of_metrics.ipynb 完成 Mean Squared Error 的函式

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

MAE = mean_absolute_error(y, y_hat)
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean absolute error is 10.779

# %%
def mean_squared_error(y, yp):
    """
    計算 MSE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mse: MSE
    """
    mse = MSE = sum(pow(y - yp, 2)) / len(y)
    return mse

MSE = mean_squared_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
# Out:
# The Mean squared error is 216.747
